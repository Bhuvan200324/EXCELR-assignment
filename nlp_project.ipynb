# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuvan200324/EXCELR-assignment/blob/main/nlp_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import string
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download("punkt_tab")
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def preprocess_text(text):
  tokenize=word_tokenize(text)
  tokenize=[word.lower() for word in tokenize if word.isalpha()]
  stop_words=set(stopwords.words('english'))
  tokenize=[word for word in tokenize if word not in stop_words]
  lemmatizer=WordNetLemmatizer()
  tokenize=[lemmatizer.lemmatize(word) for word in tokenize]
  return ' '.join(tokenize)

# %%
review1='The movie was so good! the acting is also good'
review2='The movie was so bad! the acting is also bad'

# %%
a=preprocess_text(review1)
b=preprocess_text(review2)
print(a)
print(b)
# Out:
# movie good acting also good
# movie bad acting also bad

# %%
vectorizer=TfidfVectorizer()
vectors=vectorizer.fit_transform([a,b])
print(vectors.toarray())
# Out:
# [[0.30287281 0.30287281 0.         0.85135433 0.30287281]
#  [0.30287281 0.30287281 0.85135433 0.         0.30287281]]

# %%
cosine_sim=cosine_similarity(vectors[0],vectors[1])[0][0]
print(round(cosine_sim,3))
# Out:
# 0.275

# %%
cosine_sim=cosine_similarity(vectors[0],vectors[0])[0][0]
print(round(cosine_sim,3))
# Out:
# 1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('train.csv')
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
df.shape
# Out:
# (27481, 4)

# %%
df['text1_clean']=df['text'].astype(str).apply(preprocess_text)
df['text2_clean']=df['selected_text'].astype(str).apply(preprocess_text)
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                       text1_clean      text2_clean
# 0                 responded going  responded going
# 1         sooo sad miss san diego         sooo sad
# 2                    bos bullying         bullying
# 3           interview leave alone      leave alone
# ...

# %%
vectorizer=TfidfVectorizer()
tfidf_matrix1=vectorizer.fit_transform(df['text1_clean'])
tfidf_matrix2=vectorizer.transform(df['text2_clean'])

# %%
cosine_sim=cosine_similarity(tfid_matrix1,tfid_matrix2)
df['cosine_similarity']=cosine_sim.diagonal()
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                       text1_clean      text2_clean  cosine_similarity
# 0                 responded going  responded going           1.000000
# 1         sooo sad miss san diego         sooo sad           0.534336
# ...

# %%
def jaccab_similarity(text1,text2):
  set1=set(text1.split())
  set2=set(text2.split())
  intersection=set1.intersection(set2)
  union=(set1).union(set2)
  jaccob_sim=len(intersection)/len(union)
  return jaccob_sim

# %%
df["jaccob_similarity"]=df.apply(lambda row:jaccab_similarity(x["text1_clean"],row["text2_clean"]),axis=1)
df.head()
